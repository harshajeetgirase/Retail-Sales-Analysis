# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Retail_Sales_Data_Ananlysis.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 CustomerID Gender Customer_City          ProductName  \
# 0           0       C001      M   Osborneport          Like Camera
# 1           1       C001      M   Osborneport          Like Camera
# 2           2       C001      M   Osborneport  Audience Television
# 3           3       C001      M   Osborneport  Audience Television
# 4           4       C001      M   Osborneport        Here Footwear
#
#       Category SubCategory  UnitPrice  CostPrice        Date  Quantity  \
# 0  Electronics      Camera    1673.69    1323.38  2025-06-28         2
# 1  Electronics      Camera    1673.69    1323.38  2023-12-21         3
# 2  Electronics  Television     818.76     527.62  2025-06-28         3
# 3  Electronics  Television     818.76     527.62  2024-04-21         3
# 4      Fashion    Footwear     337.63     169.03  2025-03-02         1
#
#    Discount  PaymentMethod                StoreName      Store_City Region
# ...

# %% [markdown]
# ## Droping unwanted Features

# %%
df.drop(columns = ['Unnamed: 0'],axis=1,inplace = True)

# %%
## Preview of the column

df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Customer_City', 'ProductName', 'Category',
#        'SubCategory', 'UnitPrice', 'CostPrice', 'Date', 'Quantity', 'Discount',
#        'PaymentMethod', 'StoreName', 'Store_City', 'Region'],
#       dtype='object')

# %% [markdown]
# ## Shape of the Data

# %%
df.shape
# Out:
# (5000, 15)

# %% [markdown]
# ## Information of the Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerID     5000 non-null   object
#  1   Gender         5000 non-null   object
#  2   Customer_City  5000 non-null   object
#  3   ProductName    5000 non-null   object
#  4   Category       5000 non-null   object
#  5   SubCategory    5000 non-null   object
#  6   UnitPrice      5000 non-null   float64
#  7   CostPrice      5000 non-null   float64
#  8   Date           5000 non-null   object
#  9   Quantity       5000 non-null   int64
#  10  Discount       5000 non-null   float64
#  11  PaymentMethod  5000 non-null   object
#  12  StoreName      5000 non-null   object
#  13  Store_City     5000 non-null   object
#  14  Region         5000 non-null   object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 586.1+ KB

# %% [markdown]
# ## converting date column object to data

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# CustomerID       0
# Gender           0
# Customer_City    0
# ProductName      0
# Category         0
# SubCategory      0
# UnitPrice        0
# CostPrice        0
# Date             0
# Quantity         0
# Discount         0
# PaymentMethod    0
# StoreName        0
# Store_City       0
# Region           0
# dtype: int64

# %% [markdown]
# ## Duplicated Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Checking Inconsistent Values

# %%
df.Gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['South', 'East', 'North', 'West'], dtype=object)

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Bank Transfer', 'Mobile Money', 'Credit Card', 'Cash'],
#       dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Electronics', 'Fashion', 'Groceries'], dtype=object)

# %%
df.Quantity.unique()
# Out:
# array([2, 3, 1, 5, 4], dtype=int64)

# %%
df.Customer_City.value_counts()
# Out:
# Customer_City
# North Chaseborough    36
# West Wandaland        36
# Port Angelabury       35
# New Jason             34
# South Briantown       34
#                       ..
# Port Jacob            15
# Hansonhaven           15
# North Jason           15
# Melissashire          15
# Quinnville            12
# Name: count, Length: 200, dtype: int64

# %%
df.to_csv('Retail_Sales_EDA.csv',index=False)

# %%
df.to_parquet('Cleaned.parquet',index = False)
