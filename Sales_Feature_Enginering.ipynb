# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet('cleaned.parquet')

# %%
df.head()
# Out:
#   CustomerID Gender Customer_City          ProductName     Category  \
# 0       C001      M   Osborneport          Like Camera  Electronics
# 1       C001      M   Osborneport          Like Camera  Electronics
# 2       C001      M   Osborneport  Audience Television  Electronics
# 3       C001      M   Osborneport  Audience Television  Electronics
# 4       C001      M   Osborneport        Here Footwear      Fashion
#
#   SubCategory  UnitPrice  CostPrice       Date  Quantity  Discount  \
# 0      Camera    1673.69    1323.38 2025-06-28         2      0.00
# 1      Camera    1673.69    1323.38 2023-12-21         3      0.05
# 2  Television     818.76     527.62 2025-06-28         3      0.05
# 3  Television     818.76     527.62 2024-04-21         3      0.05
# 4    Footwear     337.63     169.03 2025-03-02         1      0.10
#
#    PaymentMethod                StoreName      Store_City Region
# 0  Bank Transfer  MegaMart Jimenezborough  Jimenezborough  South
# 1   Mobile Money       MegaMart Peckmouth       Peckmouth   East
# 2  Bank Transfer  MegaMart Jimenezborough  Jimenezborough  South
# 3    Credit Card     MegaMart Brianahaven     Brianahaven  North
# 4   Mobile Money     MegaMart Brianahaven     Brianahaven  North

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerID     5000 non-null   object
#  1   Gender         5000 non-null   object
#  2   Customer_City  5000 non-null   object
#  3   ProductName    5000 non-null   object
#  4   Category       5000 non-null   object
#  5   SubCategory    5000 non-null   object
#  6   UnitPrice      5000 non-null   float64
#  7   CostPrice      5000 non-null   float64
#  8   Date           5000 non-null   datetime64[ns]
#  9   Quantity       5000 non-null   int64
#  10  Discount       5000 non-null   float64
#  11  PaymentMethod  5000 non-null   object
#  12  StoreName      5000 non-null   object
#  13  Store_City     5000 non-null   object
#  14  Region         5000 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(10)
# memory usage: 586.1+ KB

# %% [markdown]
# ## 1. Create Revenue
#
# Revenue = UnitPrice × Quantity × (1 - Discount)

# %%
df['Revenue'] = df['UnitPrice'] * df['Quantity'] * (1 - df['Discount'])

# %% [markdown]
# ## 2. Create Profit
#
# Profit = (UnitPrice – CostPrice) × Quantity

# %%
df['Profit'] = (df['UnitPrice'] - df['CostPrice']) * df['Quantity']

# %% [markdown]
# ## 3. Profit Margin %
# Helps compare which product/category gives maximum return

# %%
df['ProfitMargin'] = df['Profit'] / df['Revenue'] * 100

# %% [markdown]
# ## 4. Extract Date Features
#
# Useful for seasonality, trend, month-wise analysis.

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df['Weekday'] = df['Date'].dt.day_name()
df['Quarter'] = df['Date'].dt.quarter

# %% [markdown]
# ## 5. Price Buckets
#
# Categorize UnitPrice : Allows comparison of high vs low priced products.

# %%
df['PriceRange'] = pd.cut(df['UnitPrice'],
                          bins=[0, 50, 200, 500, 2000],
                          labels=['Low', 'Medium', 'High', 'Premium'])

# %% [markdown]
# ## 6. Discount Buckets
#
# Helps see profit loss due to discounts.

# %%
df['DiscountLevel'] = pd.cut(
    df['Discount'],
    bins=[-0.01, 0.05, 0.15, 0.30, 1.0],
    labels=['Low', 'Medium', 'High', 'Very High']
)

# %% [markdown]
# ## 7. Total Cost

# %%
df['TotalCost'] = df['CostPrice'] * df['Quantity']

# %%
df.to_parquet("feature_enginnering.parquet")
